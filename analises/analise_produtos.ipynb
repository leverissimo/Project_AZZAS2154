# %% [markdown]
# ## Análise de produtos

# %%
import pandas as pd
import numpy as np
import os
import datetime

# Froms
from gcpUtils.auth import getCredentials
from gcpUtils.bigQuery import pandasToBq, tableToPandas
from gcpUtils.google_storage_manager import *

# %%
# Definição das credenciais 
cred = getCredentials("../bd/planejamento-animale-292719-296d49ccdea6.json")

# %% [markdown]
# ### Primeira análise

# %%
query = """
SELECT FILIAL, SKU, DATA, RESSUPRIR, ALVO
FROM `planejamento-animale-292719.checklists_rollout.ANIMALE_checklist`
WHERE DATA > '2025-01-15' AND DATA < '2025-10-06'
AND FILIAL LIKE 'ANIMALE MARINGA CM'
ORDER BY DATA;
"""


df_prod_desc = tableToPandas(query, 'planejamento-animale-292719', cred)
df_prod_desc.columns = df_prod_desc.columns.str.upper()

print(df_prod_desc)
# colunas do bd
colunas_bd = df_prod_desc.columns.tolist()
df_prod_desc = df_prod_desc[colunas_bd]
# Salvar como Excel
df_prod_desc.to_excel("rupturas_buzios.xlsx", index=False, sheet_name="Dados")
# Out:
#                    FILIAL                     SKU        DATA  RESSUPRIR  ALVO
# 0      ANIMALE MARINGA CM   03.01.1709-0003-TAM_1  2025-01-18        0.0   1.0
# 1      ANIMALE MARINGA CM   03.01.1709-0003-TAM_2  2025-01-18        0.0   1.0
# 2      ANIMALE MARINGA CM  03.01.1741-10065-TAM_3  2025-01-18        0.0   1.0
# 3      ANIMALE MARINGA CM  03.01.1741-10065-TAM_4  2025-01-18        0.0   1.0
# 4      ANIMALE MARINGA CM  03.01.1741-10065-TAM_5  2025-01-18        0.0   1.0
# ...                   ...                     ...         ...        ...   ...
# 47891  ANIMALE MARINGA CM  52.39.0365-51408-TAM_3  2025-06-18        0.0   1.0
# 47892  ANIMALE MARINGA CM   52.39.0367-0005-TAM_1  2025-06-18        0.0   1.0
# 47893  ANIMALE MARINGA CM   52.39.0371-0024-TAM_3  2025-06-18        0.0   1.0
# 47894  ANIMALE MARINGA CM  52.39.0375-10056-TAM_3  2025-06-18        0.0   1.0
# 47895  ANIMALE MARINGA CM  52.39.0375-10056-TAM_4  2025-06-18        0.0   1.0
#
# [47896 rows x 5 columns]
